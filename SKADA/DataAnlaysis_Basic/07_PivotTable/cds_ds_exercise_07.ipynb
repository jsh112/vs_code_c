# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

# 경고 무시
warnings.filterwarnings('ignore')

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## apply() - 함수를 적용
#
# `apply()`는 데이터 전처리 시 굉장히 많이 활용하는 기능입니다.
#
# 좀 더 복잡한 **logic을 컬럼 또는 데이터프레임에 적용**하고자 할 때 사용합니다.

# %%
df1 = df.copy()
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **who** 컬럼에 대하여 man은 남자, woman은 여자, child는 아이로 변경하고자 한다면 apply를 활용하여 해결

# %%
df1['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %% [markdown]
# ### 함수 정의

# %%
def transform_who(x):
    if x == 'man':
        return '남자'
    elif x == 'woman':
        return '여자'
    else:
        return '아이'

# %%
df1['who'].apply(transform_who)
# Out:
# 0      남자
# 1      여자
# 2      여자
# 3      여자
# 4      남자
#        ..
# 886    남자
# 887    여자
# 888    여자
# 889    남자
# 890    남자
# Name: who, Length: 891, dtype: object

# %%
df1['who'].apply(transform_who).value_counts()
# Out:
# who
# 남자    537
# 여자    271
# 아이     83
# Name: count, dtype: int64

# %%
def transform_who(x):
    return x['fare'] / x['age']

# %%
df1.apply(transform_who, axis=1)
# Out:
# 0      0.329545
# 1      1.875876
# 2      0.304808
# 3      1.517143
# 4      0.230000
#          ...
# 886    0.481481
# 887    1.578947
# 888         NaN
# 889    1.153846
# 890    0.242188
# Length: 891, dtype: float64

# %% [markdown]
# ## apply() - lambda function
#
# 간단한 로직은 함수를 굳이 만들지 않고 lambda함수로 쉽게 해결

# %%
df1['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1['survived'].apply(lambda x:'생존' if x == 1 else '사망')
# Out:
# 0      사망
# 1      생존
# 2      생존
# 3      생존
# 4      사망
#        ..
# 886    사망
# 887    생존
# 888    사망
# 889    생존
# 890    사망
# Name: survived, Length: 891, dtype: object

# %%
df1['survived'].apply(lambda x:'생존' if x == 1 else '사망').value_counts()
# Out:
# survived
# 사망    549
# 생존    342
# Name: count, dtype: int64

# %% [markdown]
# ### 연습문제

# %%
sample = df.copy()
sample.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# sample 데이터 프레임에 대하여 apply를 활용하여 class 컬럼의 값을 다음과 같이 바꾸고, 분포를 출력 후 변경 전과 동일한지 확인하세요

# %%
sample['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
def transform_class(x):
    if x == 'Third':
        return '삼등석'
    elif x == 'Second':
        return '이등석'
    else:
        return '일등석'

# %%
sample['class'].apply(transform_class)
# Out:
# 0      삼등석
# 1      일등석
# 2      삼등석
# 3      일등석
# 4      삼등석
#       ...
# 886    이등석
# 887    일등석
# 888    삼등석
# 889    일등석
# 890    삼등석
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['일등석', '이등석', '삼등석']

# %%
sample['class'].apply(transform_class).value_counts()
# Out:
# class
# 삼등석    491
# 일등석    216
# 이등석    184
# Name: count, dtype: int64

# %% [markdown]
# <p><strong>[출력 결과]</strong></p><pre>삼등석    491
# 일등석    216
# 이등석    184
# Name: class, dtype: int64</pre>

# %% [markdown]
# ## groupby() - 그룹
#
# 데이터를 특정 기준으로 그룹핑할 때 활용합니다. 엑셀의 피봇테이블과 유사합니다.
#
# **참고링크**
# - [판다스(Pandas) .groupby()로 할 수 있는 거의 모든 것!](https://teddylee777.github.io/pandas/pandas-groupby)
#
# ![](https://www.w3resource.com/w3r_images/pandas-groupby-split-apply-combine.svg)

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 타이타닉 호의 생존자와 사망자를 성별 기주으로 그룹핑하여 평균을 살펴보겠습니다.

# %%
df.groupby('sex').mean(numeric_only=True)
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %% [markdown]
# `groupby()`를 사용할 때는 반드시 aggregate 하는 **통계함수와 일반적으로 같이 적용**합니다.

# %% [markdown]
# ### 2개 이상의 컬럼으로 그룹
#
# 2개 이상의 컬럼으로 그룹핑할 때도 list로 묶어서 지정하면 됩니다.

# %%
# 성별, 좌석등급 별 통계
df.groupby(['sex', 'pclass']).mean(numeric_only=True)
# Out:
#                survived        age     sibsp     parch        fare  \
# sex    pclass
# female 1       0.968085  34.611765  0.553191  0.457447  106.125798
#        2       0.921053  28.722973  0.486842  0.605263   21.970121
#        3       0.500000  21.750000  0.895833  0.798611   16.118810
# male   1       0.368852  41.281386  0.311475  0.278689   67.226127
#        2       0.157407  30.740707  0.342593  0.222222   19.741782
#        3       0.135447  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    pclass
# female 1         0.000000  0.361702
#        2         0.000000  0.421053
#        3         0.000000  0.416667
# male   1         0.975410  0.614754
#        2         0.916667  0.666667
#        3         0.919308  0.760807

# %% [markdown]
# ### 1개의 특정 컬럼에 대한 결과 도출
#
# 우리의 주요 관심사는 survived 컬럼. 만약 survived 컬럼에 대한 결과만 도출하고 싶으면 컬럼을 맨 끝에 지정

# %%
df.groupby(['sex', 'pclass'])['survived'].mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %% [markdown]
# 예쁘게 출력하려면 `pd.DataFrame()`으로 감싸주거나, `survived` 컬럼을 []로 한 번 더 감싸주면 됩니다.

# %%
pd.DataFrame(df.groupby(['sex', 'pclass'])['survived'].mean())
# Out:
#                survived
# sex    pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
df.groupby(['sex', 'pclass'])[['survived']].mean()
# Out:
#                survived
# sex    pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %% [markdown]
# ### reset_index(): 인덱스 초기화
#
# `reset_index()`: 그룹핑된 데이터프레임의 **index를 초기화**하여 새로운 데이터프레임을 생성합니다.

# %%
df.groupby(['sex', 'pclass'])[['survived']].mean().reset_index()
# Out:
#       sex  pclass  survived
# 0  female       1  0.968085
# 1  female       2  0.921053
# 2  female       3  0.500000
# 3    male       1  0.368852
# 4    male       2  0.157407
# 5    male       3  0.135447

# %% [markdown]
# ### 다중 컬럼에 대한 결과 도출
#
# 끝에 단일 컬럼이 아닌 여러 개의 컬럼을 지정합니다.

# %%
df.groupby(['sex', 'pclass'])[['survived', 'age']].mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.968085  34.611765
#        2       0.921053  28.722973
#        3       0.500000  21.750000
# male   1       0.368852  41.281386
#        2       0.157407  30.740707
#        3       0.135447  26.507589

# %% [markdown]
# ### 다중 통계 함수 적용
#
# 여러 가지의 통계 값을 적용할 때는 `agg()`를 사용합니다.

# %%
# 성별, 좌석등급 별 통계
df.groupby(['sex', 'pclass'])[['survived', 'age']].agg(['mean', 'sum'])
# Out:
#                survived            age
#                    mean sum       mean      sum
# sex    pclass
# female 1       0.968085  91  34.611765  2942.00
#        2       0.921053  70  28.722973  2125.50
#        3       0.500000  72  21.750000  2218.50
# male   1       0.368852  45  41.281386  4169.42
#        2       0.157407  17  30.740707  3043.33
#        3       0.135447  47  26.507589  6706.42

# %% [markdown]
# ## 연습문제

# %%
sample = df.copy()
sample.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# `groupby()`를 활용하여 pclass별 생존율을 출력하세요

# %% [markdown]
# survived column에서 생존 1, 사망 0이므로
#
# (생존자 수) / 전체 인원 = 생존률인데 1 * 생존자수 / 전체인원이므로 mean()과 같다

# %%
sample.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %% [markdown]
# <p><strong>[출력 결과]</strong></p><pre>pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64</pre>
