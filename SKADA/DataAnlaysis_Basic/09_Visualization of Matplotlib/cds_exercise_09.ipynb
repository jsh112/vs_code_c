# %% [markdown]
# ## matplotlib.pyplot의 기본적인 canvas 그리기와 스타일링 예제

# %% [markdown]
# [pyplot 공식 도큐먼트 살펴보기](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)

# %% [markdown]
# 본 튜토리얼은 matplotlib의 가장 기본적인 튜토리얼을 제공합니다.
#
# 다양한 옵션값과 스타일 기본 설정법을 배울 수 있습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# Unicode warning 제거 (폰트 관련 경고메시지)
plt.rcParams['axes.unicode_minus']=False
# 그래프 출력 사이즈 설정
plt.rcParams["figure.figsize"] = (8, 8)

# %% [markdown]
# ### 단일 그래프 생성

# %%
# data 생성
data = np.arange(1, 100)
# plot
plt.plot(data)
# 그래프를 보여주는 코드
plt.show()

# %% [markdown]
# ### 다중 그래프 (multiple graphs)

# %% [markdown]
# 1개의 canvas 안에 다중 그래프 그리기

# %%
data = np.arange(1, 51)
plt.plot(data)

data2 = np.arange(51, 101)
# plt.figure()
plt.plot(data2)

plt.show()

# %% [markdown]
# 2개의 figure로 나누어서 다중 그래프 그리기
#
# - figure()는 새로운 그래프 canvas를 생성합니다.

# %%
data = np.arange(100, 201)
plt.plot(data)

data2 = np.arange(200, 301)
# figure() function makes a new graph
plt.figure()
plt.plot(data2)

plt.show()

# %% [markdown]
# ### 여러개의 plot을 그리는 방법 (subplot)
#
# plt.subplot(row, column, index)

# %%
data = np.arange(100, 201)
plt.subplot(2, 1, 1)
plt.plot(data)

data2 = np.arange(200, 301)
plt.subplot(2, 1, 2)
plt.plot(data2)
plt.show()

# %% [markdown]
# 위의 코드와 동일하나 , (콤마)를 제거한 상태

# %%
data = np.arange(100, 201)
# comma를 생략하고 row, culumn, index로 작성가능
#211 -> row:2, col:1, index:1
plt.subplot(211)
plt.plot(data)

data2 = np.arange(200, 301)
plt.subplot(212)
plt.plot(data2)
plt.show()

# %%
data = np.arange(100, 201)
plt.subplot(1, 3, 1)
plt.plot(data)

data2 = np.arange(200, 301)
plt.subplot(1, 3, 2)
plt.plot(data2)

data3 = np.arange(300, 401)
plt.subplot(1, 3, 3)
plt.plot(data3)

# %% [markdown]
# ### 여러 개의 plot을 그리는 방법 (subplots) - s가 더 붙습니다

# %% [markdown]
# plt.subplots(numbers of row, numbers of column)

# %%
data = np.arange(1, 51)
# create the data

# plot
fig, axes = plt.subplots(2, 3)

axes[0, 0].plot(data)
axes[0, 1].plot(data * data)
axes[0, 2].plot(data ** 3)
axes[1, 0].plot(data % 10)
axes[1, 1].plot(-data)
axes[1, 2].plot(data // 20)

plt.tight_layout()
plt.show()

# %%
from IPython.display import Image

# 출처: matplotlib.org
Image('https://matplotlib.org/_images/anatomy.png')

# %%
plt.plot([1, 2, 3], [3, 6, 9])
plt.plot([1, 2, 3], [2, 4, 9])
# 타이틀 & font 설정
plt.title('이것은 타이틀 입니다')

plt.show()

# %%
plt.plot([1, 2, 3], [3, 6, 9])
plt.plot([1, 2, 3], [2, 4, 9])
# 타이틀  & font 설정
plt.title('타이틀 fontsize를 키웁니다', fontsize=20)
plt.show()

# %% [markdown]
# ### X, Y축 Label 설정

# %%
plt.plot([1, 2, 3], [3, 6, 9])
plt.plot([1, 2, 3], [2, 4, 9])

plt.title('Label setting example', fontsize=20)

plt.xlabel('x axis', fontsize=20)
plt.ylabel('y axis', fontsize=20)
# Out:
# Text(0, 0.5, 'y axis')

# %% [markdown]
# ### X, Y축 Tick 설정 (rotation)
#
# Tick은 X, Y축에 위치한 눈금을 말합니다.

# %%
plt.plot(np.arange(10), np.arange(10)*2)
plt.plot(np.arange(10), np.arange(10)**2)
plt.plot(np.arange(10), np.log(np.arange(10)*2))

# title and font setting

plt.title('Set the x, y axis', fontsize=20)

# set the x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set the ticks of x, y
plt.xticks(rotation=90)
plt.yticks(rotation=30)
plt.show()

# %% [markdown]
# ### 범례(Legend) 설정

# %%
plt.plot(np.arange(10), np.arange(10)*2)
plt.plot(np.arange(10), np.arange(10)**2)
plt.plot(np.arange(10), np.log(np.arange(10)*2))

# title and font setting

plt.title('Set the x, y axis', fontsize=20)

# set the x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set the ticks of x, y
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.legend(['10 * 2', '10 ** 2', 'log'], fontsize=20)

# set x, y limits
plt.xlim(0, 5)
plt.ylim(0.5, 10)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2)
plt.plot(np.arange(10), np.arange(10)**2)
plt.plot(np.arange(10), np.log(np.arange(10)*2))

# title and font setting

plt.title('Set the x, y axis', fontsize=20)

# set the x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# %% [markdown]
# ### 스타일 세부 설정 = 마커, 라인, 컬러
#
# 스타일 세부 설정은 마커, 선의 종류 설정, 그리고 컬러가 있으며, 문자열로 세부 설정을 하게 됩니다.

# %% [markdown]
# **marker의 종류**
#
# - '.' point marker
# - ',' pixel marker
# - 'o' circle marker
# - 'v' triangle_down marker
# - '^' triangle_up marker
# - '<' triangle_left marker
# - '>' triangle_right marker
# - '1' tri_down marker
# - '2' tri_up marker
# - '3' tri_left marker
# - '4' tri_right marker
# - 's' square marker
# - 'p' pentagon marker
# - '*' star marker
# - 'h' hexagon1 marker
# - 'H' hexagon2 marker
# - '+' plus marker
# - 'D' diamond marker
# - 'd' thin_diamond marker
# - '|' vline marker
# - '_' hline marker

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', markersize=5)
plt.plot(np.arange(10), np.arange(10)*2 - 10, marker='v', markersize=10)
plt.plot(np.arange(10), np.arange(10)*2 - 20, marker='+', markersize=15)
plt.plot(np.arange(10), np.arange(10)*2 - 30, marker='*', markersize=20)

# set title and font
plt.title('setting marker example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()

# %% [markdown]
# **line의 종류**
#
# - '-' solid line style
# - '--' dashed line style
# - '-.' dash-dot line style
# - ':' dotted line style

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', linestyle='')
plt.plot(np.arange(10), np.arange(10)*2 - 10, marker='o', linestyle='-')
plt.plot(np.arange(10), np.arange(10)*2 - 20, marker='v', linestyle='--')
plt.plot(np.arange(10), np.arange(10)*2 - 30, marker='+', linestyle='-.')
plt.plot(np.arange(10), np.arange(10)*2 - 40, marker='*', linestyle=':')

# set title and font
plt.title('setting marker example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', linestyle='-', color='b')
plt.plot(np.arange(10), np.arange(10)*2 - 10, marker='v', linestyle='--', color='c')
plt.plot(np.arange(10), np.arange(10)*2 - 20, marker='+', linestyle='-.', color='y')
plt.plot(np.arange(10), np.arange(10)*2 - 30, marker='*', linestyle=':', color='r')

# set title and font
plt.title('setting color example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2, color='b', alpha=0.1)
plt.plot(np.arange(10), np.arange(10)*2 - 10, color='b', alpha=0.3)
plt.plot(np.arange(10), np.arange(10)*2 - 20, color='b', alpha=0.6)
plt.plot(np.arange(10), np.arange(10)*2 - 30, color='b', alpha=1.0)

# set title and font
plt.title('setting alpha example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()

# %% [markdown]
# ### Grid setting

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', linestyle='-', color='b')
plt.plot(np.arange(10), np.arange(10)*2 - 10, marker='v', linestyle='--', color='c')
plt.plot(np.arange(10), np.arange(10)*2 - 20, marker='+', linestyle='-.', color='y')
plt.plot(np.arange(10), np.arange(10)*2 - 30, marker='*', linestyle=':', color='r')

# set title and font
plt.title('setting alpha example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.grid()

plt.show()

# %% [markdown]
# ### annotate 설정

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', color='b', linestyle='-')
plt.plot(np.arange(10), np.arange(10)*2 - 10, marker='v', linestyle='--', color='c')
plt.plot(np.arange(10), np.arange(10)*2 - 20, marker='+', linestyle='-.', color='y')
plt.plot(np.arange(10), np.arange(10)*2 - 30, marker='*', linestyle=':', color='r')

# set title and font
plt.title('setting alpha example', fontsize=20)

# set x, y labels
plt.xlabel('axis-x', fontsize=20)
plt.ylabel('axis-y', fontsize=20)

# set ticks of x, y axis
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.grid()

plt.annotate('outbreak onset point', xy=(3, -20), xytext=(3, -25), arrowprops=dict(facecolor='black', shrink=0.05))

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2)
plt.plot(np.arange(10), np.arange(10)**2)
plt.plot(np.arange(10), np.log(np.arange(10)*2))

# title
plt.title('범례 설정 예제입니다.', fontsize=20)

# label
plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.legend(['10 * 2', '10 ** 2', 'log'], fontsize=15)
